# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
2+2
# Out:
# 4

# %%
50-5*6
# Out:
# 20

# %%
(50-5*6)/4
# Out:
# 5.0

# %%
17/3
# Out:
# 5.666666666666667

# %%
17//3
# Out:
# 5

# %%
17%3
# Out:
# 2

# %%
5**2  #5제곱
# Out:
# 25

# %%
2**7  #2의 7승
# Out:
# 128

# %%
width =20    #넓이

# %%
height =5*9  #길이

# %%
width*height
# Out:
# 900
